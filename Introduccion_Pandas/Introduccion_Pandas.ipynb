# %%
import pandas as pd

""""Crear una serie a partir de una lsita:
En términos de Pandas, “crear una serie a partir de una lista” significa tomar una lista de Python (list) 
y convertirla en un objeto, que es la estructura unidimensional de Pandas.

Piensa que la lista es como un inventario en bruto (sin etiquetas ni formato).
Cuando lo pasas a una Serie, Pandas le asigna un índice (como códigos de producto) y lo transforma en un activo más organizado 
y fácil de consultar, analizar y manipular."""

#crear una serie a partir de una lista
#data=[10, 20, 30, 40, 50]
#se crea el objeto "serie" que conendra la lista "data"
#serie=pd.Series(data)
#print(serie)

"""Crear un DataFrame a partir de un diccionario:"""

""" datos = {
    'Nombre': ['Ana', 'Luis', 'Pedro'],
    'Edad': [23, 34, 45],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia']
} """

#creamos un objeto de dataframe para llamar al modulo y a la clase
#df=pd.DataFrame(datos)
#mostramos el DataFrame en consola
#print(df)

"""Creamos una base de datos en excel en formato csv y leemos con Pandas"""

#leer el archivo
#df=pd.read_csv('Bases_datos/Lista_cafe.csv',sep=';')
#print(df)

"""Metodo Head: head() es un método del DataFrame en pandas que muestra las primeras N filas del DataFrame, por defecto las primeras 5."""

#leer el archivo csv y mostrar las 5 primeras lineas
#df=pd.read_csv('Bases_datos/Lista_cafe.csv',sep=';')
#print(df.head(5))

"""Filtros mediante programacion procedimental"""

datos = {
    'Nombre': ['Ana', 'Luis', 'Pedro','Percy','Katy','Darwin','Ryu','Ericka'],
    'Edad': [23,34,45,30,25,35,6,42],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia','Arequipa','Ocongata','Cusco','Cusco','Arequipa']
}
df=pd.DataFrame(datos)
#print(df)
#Para hacer el filtro usamos:
#print(df['Nombre'])
#filtro por edad >30
mayores_30=df[df['Edad']>30]
#print(mayores_30)

"""Contar elementos de las listas (programacion procedimental)"""

def contar_lista(diccionario):
    for clave,lista in diccionario.items():
        print(f'{clave}: {len(lista)} elementos')
        
#contar_lista(datos)

"""utilizando un poco de estadistica descriptiva con la funcion 'desscribe'"""

data={
    'Edad':[28,22,35,32,45,30,26],
    'Salario':[50000,48000,52000,51000,58000,49000,47000]
}
df=pd.DataFrame(data)
print(df.describe())
# Out:
#             Edad       Salario
# count   7.000000      7.000000
# mean   31.142857  50714.285714
# std     7.403345   3638.419332
# min    22.000000  47000.000000
# 25%    27.000000  48500.000000
# 50%    30.000000  50000.000000
# 75%    33.500000  51500.000000
# max    45.000000  58000.000000
